# %%
import os
Home = os.getcwd()
print(Home)
# Out:
# /content

# %%
# !pip install ultralytics

display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.5/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
#https://universe.roboflow.com/freedomtech/plastic-trash-freedomtech --> dataset link!mkdir {Home}/datasets
# %cd {Home}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="yourkey")
project = rf.workspace("freedomtech").project("plastic-trash-freedomtech")
version = project.version(1)
dataset = version.download("yolov11")

# %%
# !yolo task=detect mode=train model=yolo11s-seg.pt data=/content/datasets/plastic-trash-freedomtech-1/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# ...
# 100% 19.7M/19.7M [00:00<00:00, 72.3MB/s]
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
